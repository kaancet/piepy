# %%
from piepy.psychophysics.wheel.discrimination.wheelDiscriminationSession import WheelDiscriminationSession, get_run_stats

# %%
exp_name = "250318_VB101_1stim_opto120_ALRL__no_cam_VO"
# exp_name = "230106_KC144_detect__no_cam_KC"
w = WheelDiscriminationSession(exp_name,
                          load_flag=False,
                          skip_google=True)
data = w.runs[0].data.data
paths = w.runs[0].paths

# %%
get_run_stats(data)

# %%
from piepy.plotters.psychophysics.progress_plot import *
from piepy.plotters.psychophysics.discrimination.psychometric_plot import plot_psychometric

# %%
plot_psychometric(data,
                  discrim_of="width",
                  outcomes=["correct","incorrect"],
                  style="print")
