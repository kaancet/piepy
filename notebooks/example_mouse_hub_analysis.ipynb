# %%
import glob
from piepy.psychophysics.wheel.detection.wheelDetectionHub import WheelDetectionHub

# %%
sessions = glob.glob("/Users/kaan/data/training/*/")

# %%
session_sub = [s for s in sessions if "KC304" in s]
session_sub

# %%
hub = WheelDetectionHub()

# %%
hub.initialize(session_sub, load_sessions=True)

# %%
hub.save("/Users/kaan/data/analysis/00_behavior")
